# %%
# Step 1: Import Python Libraries

# The first step involved in ML using python is understanding and playing around with our data using libraries. 
# Import all libraries which are required for our analysis, such as Data Loading, Statistical analysis, Visualizations, 
# Data Transformations, Merge and Joins, etc.
# Pandas and Numpy have been used for Data Manipulation and numerical Calculations
# Matplotlib and Seaborn have been used for Data visualizations. 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Step 2: Reading Dataset
CreditCardData = pd.read_csv("23Q2-CreditCardBalances.csv")

# %%
CreditCardData.shape
# Out:
# (48, 28)

# %%
#Analyzing the Data
#The main goal of data understanding is to gain general insights about the data, 
# which covers the number of rows and columns, values in the data, datatypes, and Missing values in the dataset.

#head() will display the top 5 observations of the dataset
CreditCardData.head()
# Out:
#     YRQTR Total Balances ($Billions)  Number of Accounts (Millions)  \
# 0  2012Q3                   $531.06                         413.320
# 1  2012Q4                   $546.20                         412.118
# 2  2013Q1                   $517.65                         410.443
# 3  2013Q2                   $524.84                         408.316
# 4  2013Q3                   $524.63                         410.613
#
#   Total Commitments ($Billions)  \
# 0                    $2,720.45
# 1                    $2,720.70
# 2                    $2,705.60
# 3                    $2,710.88
# 4                    $2,710.10
#
#   Account Balance (Active Accounts Only) (50th percentile)  \
# 0                                              $353
# 1                                              $388
# 2                                              $322
# 3                                              $311
# 4                                              $304
#
# ...

# %%
#tail() will display the last 5 observations of the dataset
CreditCardData.tail()

# RESULT: 
# CreditCardData.tail() shows the variable YRQTR has more values and they did not relaitive with the Years. 
# The rows from 44 to 47 should be remove from our data set.
# Out:
#                                                 YRQTR  \
# 43                                             2023Q2
# 44                                                NaN
# 45             Source: Philadelphia Fed FR Y-14M Data
# 46  Website: https://www.philadelphiafed.org/surve...
# 47             Email: Phil.LargeBankData@phil.frb.org
#
#    Total Balances ($Billions)  Number of Accounts (Millions)  \
# 43                   $782.22                         475.423
# 44                        NaN                            NaN
# 45                        NaN                            NaN
# 46                        NaN                            NaN
# 47                        NaN                            NaN
#
#    Total Commitments ($Billions)  \
# 43                    $3,976.18
# 44                           NaN
# 45                           NaN
# 46                           NaN
# 47                           NaN
#
# ...

# %%
#info() helps to understand the data type and information about data, including the number of records in each column,
# data having null or not null, Data type, the memory usage of the dataset

CreditCardData.info()

# RESULT: 
# CreditCardData.info() shows the all variables have equal number of values exept 'YRQTR' variable which 
# has did not relaitive data in the end of data set from the Index 44 to 47. We can see it using CreditCardData.tail().
# They should be cleaned! 
# And variable '% of Accounts with Credit Line Decrease' has one missed value. But that column I do not need for my analysis. 
# I will dpor that field.# 
# Unfotunetly, Numeric variables were not correctly intrapritered.
# They should be changed from object datatype to float64 or int64.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 28 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   YRQTR                                                                                     47 non-null     object
#  1   Total Balances ($Billions)                                                                44 non-null     object
#  2   Number of Accounts (Millions)                                                             44 non-null     float64
#  3   Total Commitments ($Billions)                                                             44 non-null     object
#  4   Account Balance (Active Accounts Only) (50th percentile)                                  44 non-null     object
# ...

# %%
# Check for Duplication
# nunique() based on several unique values in each column and the data description,
# we can identify the continuous and categorical columns in the data.
# Duplicated data can be handled or removed based on further analysis

CreditCardData.nunique()
# Out:
# YRQTR                                                                                       47
# Total Balances ($Billions)                                                                  44
# Number of Accounts (Millions)                                                               44
# Total Commitments ($Billions)                                                               44
# Account Balance (Active Accounts Only) (50th percentile)                                    39
# Account Balance (Active Accounts Only) (75th percentile)                                    40
# Account Balance (Active Accounts Only) (90th percentile)                                    44
# Current Credit Limit (50th Percentile)                                                      16
# Current Credit Limit (75th Percentile)                                                      15
# Current Credit Limit (90th Percentile)                                                      23
# ...

# %%
# Missing Values Calculation

# isnull() is widely been in all pre-processing steps to identify null values in the data
# In our example, data.isnull().sum() is used to get the number of missing records in each column
CreditCardData.isnull().sum()
# Out:
# YRQTR                                                                                       1
# Total Balances ($Billions)                                                                  4
# Number of Accounts (Millions)                                                               4
# Total Commitments ($Billions)                                                               4
# Account Balance (Active Accounts Only) (50th percentile)                                    4
# Account Balance (Active Accounts Only) (75th percentile)                                    4
# Account Balance (Active Accounts Only) (90th percentile)                                    4
# Current Credit Limit (50th Percentile)                                                      4
# Current Credit Limit (75th Percentile)                                                      4
# Current Credit Limit (90th Percentile)                                                      4
# ...

# %%
# The below code helps to calculate the percentage of missing values in each column
# (CreditCardData.isnull().sum()/(len(CreditCardData)))*100

#RESULT: The percentage of missing values for the columns New_Price and Price is ~86% and ~17%, respectively.
# Out:
# YRQTR                                                                                        2.083333
# Total Balances ($Billions)                                                                   8.333333
# Number of Accounts (Millions)                                                                8.333333
# Total Commitments ($Billions)                                                                8.333333
# Account Balance (Active Accounts Only) (50th percentile)                                     8.333333
# Account Balance (Active Accounts Only) (75th percentile)                                     8.333333
# Account Balance (Active Accounts Only) (90th percentile)                                     8.333333
# Current Credit Limit (50th Percentile)                                                       8.333333
# Current Credit Limit (75th Percentile)                                                       8.333333
# ...

# %%
# Step 3: Data Reduction

# Some columns or variables can be dropped if they do not add value to our analysis.
# In our dataset, the column YRQTR has not relative data at the end of the data set. 
# Remove all rows from index 44 to the end (index 47).
CreditCardData = CreditCardData.drop(CreditCardData.index[44:])
CreditCardData.tail()
# Out:
#      YRQTR Total Balances ($Billions)  Number of Accounts (Millions)  \
# 39  2022Q2                   $675.86                         461.187
# 40  2022Q3                   $709.26                         465.727
# 41  2022Q4                   $762.56                         468.599
# 42  2023Q1                   $746.56                         472.930
# 43  2023Q2                   $782.22                         475.423
#
#    Total Commitments ($Billions)  \
# 39                    $3,667.63
# 40                    $3,743.68
# 41                    $3,804.79
# 42                    $3,895.03
# 43                    $3,976.18
#
#    Account Balance (Active Accounts Only) (50th percentile)  \
# 39                                              $357
# 40                                              $386
# 41                                              $451
# 42                                              $389
# 43                                              $421
#
# ...

# %%
# Remove all columns from  'Account Balance (Active Accounts Only) (50th percentile)' 
# to '90+ Days Past Due Rates: Balances Based'.
# ix or loc removing columns between two column names. 
#CreditCardData.drop(CreditCardData.ix[:, 'B':'D'].columns, axis=1)
# or Remove all columns between column index 
#CreditCardData.drop(CreditCardData.iloc[:, 1:3], inplace=True, axis=1)
 
CreditCardData = CreditCardData.drop(CreditCardData.loc[:, 'Account Balance (Active Accounts Only) (50th percentile)':'90+ Days Past Due Rates: Balances Based'].columns, axis=1)
CreditCardData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 8 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   YRQTR                                                                                     44 non-null     object
#  1   Total Balances ($Billions)                                                                44 non-null     object
#  2   Number of Accounts (Millions)                                                             44 non-null     float64
#  3   Total Commitments ($Billions)                                                             44 non-null     object
#  4   Share of Accounts Making the Minimum Payment                                              44 non-null     object
# ...

# %%
# # We start our Feature Engineering as we need to add some columns required for analysis.

# Step 4: Feature Engineering

# Feature engineering refers to the process of using domain knowledge to select 
# and transform the most relevant variables from raw data when creating a predictive model 
# using machine learning or statistical modeling. 
# The main goal of Feature engineering is to create meaningful data from raw data.

# %%
CreditCardData.head()
# Out:
#     YRQTR Total Balances ($Billions)  Number of Accounts (Millions)  \
# 0  2012Q3                   $531.06                         413.320
# 1  2012Q4                   $546.20                         412.118
# 2  2013Q1                   $517.65                         410.443
# 3  2013Q2                   $524.84                         408.316
# 4  2013Q3                   $524.63                         410.613
#
#   Total Commitments ($Billions) Share of Accounts Making the Minimum Payment  \
# 0                    $2,720.45                                         7.67%
# 1                    $2,720.70                                         8.78%
# 2                    $2,705.60                                         8.05%
# 3                    $2,710.88                                         7.82%
# 4                    $2,710.10                                         7.65%
#
#   Share of Accounts Making Greater Than the Minimum Payment but Less Than the Full Balance  \
# ...

# %%
# Rename columns

CreditCardData.rename(columns={'Share of Accounts Making the Minimum Payment': 'Share of Accounts Making the Minimum Payment (%Percentage)'},inplace=True)
CreditCardData.rename(columns={'Share of Accounts Making Greater Than the Minimum Payment but Less Than the Full Balance': 'Share of Accounts Making Greater Than the Minimum Payment but Less Than the Full Balance (%Percentage)'},inplace=True)
CreditCardData.rename(columns={'Share of Accounts Making Full Balance Payment': 'Share of Accounts Making Full Balance Payment (%Percentage)'},inplace=True)

CreditCardData.head()
# Out:
#     YRQTR Total Balances ($Billions)  Number of Accounts (Millions)  \
# 0  2012Q3                   $531.06                         413.320
# 1  2012Q4                   $546.20                         412.118
# 2  2013Q1                   $517.65                         410.443
# 3  2013Q2                   $524.84                         408.316
# 4  2013Q3                   $524.63                         410.613
#
#   Total Commitments ($Billions)  \
# 0                    $2,720.45
# 1                    $2,720.70
# 2                    $2,705.60
# 3                    $2,710.88
# 4                    $2,710.10
#
#   Share of Accounts Making the Minimum Payment (%Percentage)  \
# 0                                              7.67%
# 1                                              8.78%
# 2                                              8.05%
# 3                                              7.82%
# 4                                              7.65%
#
# ...

# %%
# Step 6: Data Cleaning/Wrangling
# Remove $, %, , symbols in the dataframe and change data type from 'object' to 'float'

CreditCardData['Total Balances ($Billions)'] = CreditCardData['Total Balances ($Billions)'].str.replace('$', '').astype(float)
CreditCardData['Total Commitments ($Billions)'] = CreditCardData['Total Commitments ($Billions)'].replace('[\$,]', '', regex=True).astype(float)
CreditCardData['Share of Accounts Making the Minimum Payment (%Percentage)'] = CreditCardData['Share of Accounts Making the Minimum Payment (%Percentage)'].str.replace('%', '').astype(float)
CreditCardData['Share of Accounts Making Greater Than the Minimum Payment but Less Than the Full Balance (%Percentage)'] = CreditCardData['Share of Accounts Making Greater Than the Minimum Payment but Less Than the Full Balance (%Percentage)'].str.replace('%', '').astype(float)
CreditCardData['Share of Accounts Making Full Balance Payment (%Percentage)'] = CreditCardData['Share of Accounts Making Full Balance Payment (%Percentage)'].str.replace('%', '').astype(float)
CreditCardData['Revolving Balances Only ($Billions)'] = CreditCardData['Revolving Balances Only ($Billions)'].str.replace('$', '').astype(float)


# Display the updated DataFrame
print(CreditCardData.head())
# Out:
#     YRQTR  Total Balances ($Billions)  Number of Accounts (Millions)  \
# 0  2012Q3                      531.06                        413.320
# 1  2012Q4                      546.20                        412.118
# 2  2013Q1                      517.65                        410.443
# 3  2013Q2                      524.84                        408.316
# 4  2013Q3                      524.63                        410.613
#
#    Total Commitments ($Billions)  \
# 0                        2720.45
# 1                        2720.70
# 2                        2705.60
# 3                        2710.88
# 4                        2710.10
#
#    Share of Accounts Making the Minimum Payment (%Percentage)  \
# 0                                               7.67
# 1                                               8.78
# 2                                               8.05
# 3                                               7.82
# 4                                               7.65
#
# ...

# %%
# Step 5: Creating Features

# To see what type of credit balance debt people have, we need to have two separate columns
# 'Revolving credit' and 'Installment credit'.
# We have 'Revolving Balances Only ($Billions)' column in our data set and 'Total Balances ($Billions)'.

# Revolving credit is when you can borrow money up to a certain limit and pay it back as you wish, like using a credit card.
# Installment credit is a loan with a set amount of money that you pay back in fixed payments over time, like a car loan or a mortgage.



# Add the column 'Installment Balances Only ($Billions)'
# using formula 'Total Balances ($Billions)' - 'Revolving Balances Only ($Billions)'.

CreditCardData['Installment Balances Only ($Billions)']=CreditCardData['Total Balances ($Billions)']-CreditCardData['Revolving Balances Only ($Billions)']
CreditCardData.head()
# Out:
#     YRQTR  Total Balances ($Billions)  Number of Accounts (Millions)  \
# 0  2012Q3                      531.06                        413.320
# 1  2012Q4                      546.20                        412.118
# 2  2013Q1                      517.65                        410.443
# 3  2013Q2                      524.84                        408.316
# 4  2013Q3                      524.63                        410.613
#
#    Total Commitments ($Billions)  \
# 0                        2720.45
# 1                        2720.70
# 2                        2705.60
# 3                        2710.88
# 4                        2710.10
#
#    Share of Accounts Making the Minimum Payment (%Percentage)  \
# 0                                               7.67
# 1                                               8.78
# 2                                               8.05
# 3                                               7.82
# 4                                               7.65
#
# ...

# %%
CreditCardData.describe().T
# Out:
#                                                     count         mean  \
# Total Balances ($Billions)                           44.0   613.822500
# Number of Accounts (Millions)                        44.0   434.953818
# Total Commitments ($Billions)                        44.0  3170.730909
# Share of Accounts Making the Minimum Payment (%...   44.0     8.507500
# Share of Accounts Making Greater Than the Minim...   44.0    30.698409
# Share of Accounts Making Full Balance Payment (...   44.0    32.277500
# Revolving Balances Only ($Billions)                  44.0   434.589773
# Installment Balances Only ($Billions)                44.0   179.232727
#
#                                                            std       min  \
# Total Balances ($Billions)                           70.201308   515.670
# Number of Accounts (Millions)                        17.464487   408.316
# Total Commitments ($Billions)                       363.113825  2705.600
# ...

# %%
# describe(include=’all’) provides a statistics summary of all data, include object, category etc
CreditCardData.describe(include='all').T
# Out:
#                                                    count unique     top freq  \
# YRQTR                                                 44     44  2012Q3    1
# Total Balances ($Billions)                          44.0    NaN     NaN  NaN
# Number of Accounts (Millions)                       44.0    NaN     NaN  NaN
# Total Commitments ($Billions)                       44.0    NaN     NaN  NaN
# Share of Accounts Making the Minimum Payment (%...  44.0    NaN     NaN  NaN
# Share of Accounts Making Greater Than the Minim...  44.0    NaN     NaN  NaN
# Share of Accounts Making Full Balance Payment (...  44.0    NaN     NaN  NaN
# Revolving Balances Only ($Billions)                 44.0    NaN     NaN  NaN
# Installment Balances Only ($Billions)               44.0    NaN     NaN  NaN
#
#                                                            mean         std  \
# YRQTR                                                       NaN         NaN
# ...

# %%
# Save the csv file
CreditCardData.to_csv('23Q2-CreditCardBalancesCLEANED.csv', index=False)

# %%
# Before we do EDA, lets separate Numerical and categorical variables for easy analysis
# cat_cols=CreditCardData.select_dtypes(include=['object']).columns
# num_cols = CreditCardData.select_dtypes(include=np.number).columns.tolist()
# print("Categorical Variables:")
# print(cat_cols)
# print("Numerical Variables:")
# print(num_cols)

# %% [markdown]
# Step 6: EDA Univariate Analysis - Data visualization

# %%
CreditCardData['YRQTR'] = pd.to_datetime(CreditCardData['YRQTR'])  # Convert 'YRQTR' to datetime format for better plotting

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(CreditCardData['YRQTR'], CreditCardData['Total Balances ($Billions)'], marker='o', linestyle='-')

# Adding labels and title
plt.xlabel('Quarter')
plt.ylabel('Total Balances ($Billions)')
plt.title('Total Balances Over Time')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

CreditCardData['YRQTR'] = pd.to_datetime(CreditCardData['YRQTR'], format='%YQ%q')  # Convert 'YRQTR' to datetime format for better plotting

# Line Plotting
plt.figure(figsize=(12, 6))

plt.plot(CreditCardData['YRQTR'], CreditCardData['Revolving Balances Only ($Billions)'], marker='o', label='Revolving Balances')
plt.plot(CreditCardData['YRQTR'], CreditCardData['Installment Balances Only ($Billions)'], marker='o', label='Installment Balances')

# Adding labels and title
plt.xlabel('Year and Quarter')
plt.ylabel('Balances ($Billions)')
plt.title('Revolving and Installment Balances Over Time')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

CreditCardData['YRQTR'] = pd.to_datetime(CreditCardData['YRQTR'], format='%YQ%q')  # Convert 'YRQTR' to datetime format for better plotting

# Filter DataFrame for only the fourth quarter of each year
df_q4 = CreditCardData[CreditCardData['YRQTR'].dt.quarter == 4]

# Sort DataFrame by 'YRQTR' for better plotting
df_q4 = df_q4.sort_values('YRQTR')

# Calculate percentage change for the fourth quarter of each year
#The pct_change() method returns a DataFrame with the percentage difference between the values for each row and, by default, the previous row.
df_q4['Percentage Change'] = df_q4['Total Balances ($Billions)'].pct_change() * 100

# Filled Area Plotting
plt.figure(figsize=(10, 6))

# Highlight positive changes in deepskyblue and negative changes in lightcoral
plt.fill_between(df_q4['YRQTR'], df_q4['Percentage Change'], where=(df_q4['Percentage Change'] >= 0), color='deepskyblue', interpolate=True, label='Positive Change')
plt.fill_between(df_q4['YRQTR'], df_q4['Percentage Change'], where=(df_q4['Percentage Change'] < 0), color='lightcoral', interpolate=True, label='Negative Change')

# Adding labels and title
plt.xlabel('Year and Quarter')
plt.ylabel('Percentage Change')
plt.title('Percentage Change in Total Balances (Q4 Only) Over Time')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

CreditCardData['YRQTR'] = pd.to_datetime(CreditCardData['YRQTR'], format='%YQ%q')  # Convert 'YRQTR' to datetime format for better plotting

# Extract the year from the datetime column
CreditCardData['Year'] = CreditCardData['YRQTR'].dt.year

# Grouped Bar Plotting by Year
plt.figure(figsize=(12, 6))

bar_width = 0.25  # Adjust the width based on your preference
bar_positions = np.arange(len(CreditCardData['Year'].unique()))

plt.bar(bar_positions - bar_width, CreditCardData.groupby('Year')['Share of Accounts Making Full Balance Payment (%Percentage)'].mean(), 
        width=bar_width, color='green', label='Full Balance Payment')
plt.bar(bar_positions, CreditCardData.groupby('Year')['Share of Accounts Making Greater Than the Minimum Payment but Less Than the Full Balance (%Percentage)'].mean(), 
        width=bar_width, color='orange', label='Greater Than Min Payment')
plt.bar(bar_positions + bar_width, CreditCardData.groupby('Year')['Share of Accounts Making the Minimum Payment (%Percentage)'].mean(), 
        width=bar_width, color='blue', label='Min Payment')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Average Percentage (%)')  # Using average percentage for each year
plt.title('Average Share of Accounts Payment Distribution Over Years')

# Adjust x-axis ticks and labels
plt.xticks(bar_positions, CreditCardData['Year'].unique())

plt.legend()
plt.show()
